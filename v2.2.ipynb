# %%
# LOG OF CHANGES
# Weer ff terug naar jupyter 
# BMI gedoetje gefixt (zie logboek)
# hierbij ook even uitgeprobeerd welke scaler beter is.
# en ook imputer

import os
import sys
clear = lambda: os.system('cls')  # On Windows System
clear()
sys.path.insert(0, r'C:\Users\linda\Dropbox\TM\Stagedocumenten\Q2 2021-2022\IDA-model-main\IDA-model\Functions')
# Import the right data packages
import pandas as pd
import numpy as np
import seaborn as sns
from v1_baseline import baseline
from v1_drop_data import drop_data
from v1_feature_selection import find_sign_features
from v1_impute_data import impute_data
from v1_impute_data2 import impute_data2
from v1_load_data import load_data
from v1_mean_ROC_curves import mean_ROC_curves
from v1_pipeline_model import pipeline_model
from v1_scale_data import scale_data
from v1_stratify import stratify
from sklearn.impute import KNNImputer
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn import model_selection
from sklearn import metrics
from sklearn.inspection import permutation_importance
from sklearn.svm import SVC
from sklearn.metrics import auc
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.linear_model import BayesianRidge
from sklearn.impute import IterativeImputer
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
from scipy.stats import mannwhitneyu
from scipy import stats
from statistics import mean
from statistics import stdev
from mlxtend.feature_selection import SequentialFeatureSelector as sfs

# Load and merge data. Define paths and columns wanted from Excel files
path_data = 'C:/Users/linda/Dropbox/TM/Stagedocumenten/Q2 2021-2022/IDA-model-main/model/v6_dataset.xlsx'
columns_data = "A:BBB"
path_labels = 'C:/Users/linda/Dropbox/TM/Stagedocumenten/Q2 2021-2022/IDA-model-main/model/IDA_aangevuld.xls'
columns_labels = "A:B"
path_phecodes = 'C:/Users/linda/Dropbox/TM/Stagedocumenten/Q2 2021-2022/IDA-model-main/model/phecodes_filled_binary.xlsx'
columns_phecodes = "A:R"
path_specialisms = 'C:/Users/linda/Dropbox/TM/Stagedocumenten/Q2 2021-2022/IDA-model-main/model/Letters_DBC_combined.xlsx'
columns_specialisms = "A:BW"
path_decimals = 'C:/Users/linda/Dropbox/TM/Stagedocumenten/Q2 2021-2022/IDA-model-main/model/afronden_features.xlsx'
columns_decimals = 'A:HI'
path_baseline = 'C:/Users/linda/Dropbox/TM/Stagedocumenten/Q2 2021-2022/IDA-model-main/model/baseline.xlsx'
columns_baseline = 'A:C'
path_extra = 'C:/Users/linda/Dropbox/TM/Stagedocumenten/Q2 2021-2022/IDA-model-main/model/v3_extra.xlsx'
columns_extra = 'A:D'
path_brieven = 'C:/Users/linda/Dropbox/TM/Stagedocumenten/Q2 2021-2022/IDA-model-main/model/v2_brieven.xlsx'
columns_brieven = 'A:BR'

# df data contains most of the features needed to build the model
df_data = load_data(path_data, columns_data)
# df labels contains the label ID/ no ID
df_labels = load_data(path_labels, columns_labels)
# df phecodes contains the data about the diagnoses a patient has, categorized into groups
df_phecodes = load_data(path_phecodes, columns_phecodes)
# df spec contains the data about what specialisms a patient visited
df_spec = load_data(path_specialisms, columns_specialisms)
# df decimal contains the amount of decimals for rounding the different features
df_decimal = load_data(path_decimals, columns_decimals)
# df baseline contains baseline characteristics age and gender
df_baseline = load_data(path_baseline, columns_baseline)
# df_extra contains extra characteristics like BMI and opnames
df_extra = load_data(path_extra, columns_extra)
# df_brieven contains the letters sent from specialisms
df_brieven = load_data(path_brieven,columns_brieven)

# Merge dataframes
df_hix_spec = df_data.merge(df_spec, on='Pt_no', how='outer')
df_hix_phecodes = df_hix_spec.merge(df_phecodes, on='Pt_no', how='outer')
# In df hix, all features are merged inside one dataframe. The specialisms, phecodes and labels are added
df_hix = df_hix_phecodes.merge(df_labels, on='Pt_no', how='inner')
# Now add all the extra features
df_ex = df_hix.merge(df_extra, on='Pt_no',how = 'inner')
# Now add the letters from the specialisms
df_all = df_ex.merge(df_brieven, on = 'Pt_no', how = 'inner')
print('Number of columns before dropped columns: ' + str(len(df_all.columns)))

# Defining thresholds for dropping rows and columns with missing data (threshold of amount of non-NA values required)
threshold_column = 0.7
threshold_row = 0.6

# Drop columns and rows with too many NaN's
df_dropped = drop_data(threshold_column, threshold_row, df_all)

print('Number of columns after dropped columns: ' + str(len(df_dropped.columns)))

# Balance set by picking random samples from no ID group # hierrr
df_ID_1 = df_dropped.loc[df_dropped['Label'] == 1.0]
df_ID_0_all = df_dropped.loc[df_dropped['Label'] == 0.0]

# To perform stratified random sampling, the gender of the ID group is checked
# Check baseline characteristics of subset
# Merge the dataframes of ID and no ID with the baseline characteristics in df baseline (age and gender)
# Exploratory data analysis
df_0_all_baseline = df_ID_0_all.merge(df_baseline, on='Pt_no', how='inner')
df_1_baseline = df_ID_1.merge(df_baseline, on='Pt_no', how='inner')
#characteristics = baseline(df_0_all_baseline, df_1_baseline)

# Stratify the data
df_control = stratify(df_0_all_baseline, df_1_baseline)

# Nou moeten de dataframes van no ID en ID weer bij elkaar 
df_comb = pd.concat([df_1_baseline,df_control])
df_comb = df_comb.drop(['Leeftijd', 'Geslacht'], axis = 1 )

# Defining empty lists needed later
tprs_RF_all = []
aucs_RF_all = []
auc_RF_all = []
spec_RF_all = []
sens_RF_all = []
accuracy_RF_all = []
tprs_RF_fin = []
aucs_RF_fin = []
auc_RF_fin = []
spec_RF_fin = [] 
sens_RF_fin = []
accuracy_RF_fin = []
tprs_SVM_fin = []
aucs_SVM_fin = [] 
auc_SVM_fin = []
spec_SVM_fin = [] 
sens_SVM_fin = []
accuracy_SVM_fin = []
accuracy_SVM_sign = []
perm_importances_dfs = []
sign_features_dfs = []

# Define the necessary figures
_, axis_RF_all = plt.subplots()
_, axis_RF_fin = plt.subplots()
_, axis_SVM_fin = plt.subplots()

# Define data and labels
labels = df_comb['Label']
data = df_comb.drop(['Pt_no', 'Label'], axis=1)

# Define ordinal, binary and continuous keys
ordinal_keys = ['Anti-epileptics', 'Psychofarmaca', 'Antacids', 'Anti-hypertensives', 'VitB12', 'Iron-tablets', 'Specialisms_hospitalization', 'Radiologic_investigations', 'Total_amount_ICD10s']
binary_keys = list(df_spec.keys()) + list(df_phecodes.keys()) + list(df_brieven.keys())
binary_keys.remove('Pt_no')
binary_keys.remove('Pt_no')
binary_keys.remove('Pt_no')
#continuous_keys = ['Length', 'BMI', 'Opnames_spec', 'Beeldvormende_verr', 'HR', 'RRsyst', 'RRdiast', 'Vrij T4', 'Hemolytische index', 'Icterische index', 'Lipemische index', 'TSH', 'Alk.Fosf.', 'ALAT', 'ASAT', 'Calcium', 'CKD-EPI eGFR', 'Glucose/PL', 'Hemoglobine', 'Kalium', 'Kreatinine', 'LDH', 'MCV', 'Natrium', 'RDW', 'Tot. Bilirubine', 'Gamma-GT', 'Ureum']
continuous_keys = ['Length', 'Opnames_spec', 'Beeldvormende_verr', 'HR', 'RRsyst', 'RRdiast', 'Vrij T4', 'Hemolytische index', 'Icterische index', 'Lipemische index', 'TSH', 'Alk.Fosf.', 'ALAT', 'ASAT', 'Calcium', 'CKD-EPI eGFR', 'Glucose/PL', 'Hemoglobine', 'Kalium', 'Kreatinine', 'LDH', 'MCV', 'Natrium', 'RDW', 'Tot. Bilirubine', 'Gamma-GT', 'Ureum', 'BMI']
# Test data splitten uit totale dataset
train_data2, test_data2 = train_test_split(df_comb, test_size=0.1, random_state=25)
train_data = train_data2.drop(['Pt_no', 'Label'], axis=1)
test_data = test_data2.drop(['Pt_no', 'Label'], axis=1)
train_label = train_data2['Label']
test_label = test_data2['Label']
# Out:
# Number of columns before dropped columns: 1569
# Number of columns after dropped columns: 199

# %%
# # Stukje code om de namen van de gedropte kolommen te kunnen printen
# for name in df_all.columns:
#    if name not in df_dropped.columns:
#        print(name)
# Out:
# Smoking
# Alcohol
# Drugs
# VG
# Cortisol
# FSH
# IGF-1
# IGF-1 SDS
# LH
# Oestradiol
# TSH1
# Androsteendion
# DHEA
# 17-OH Progesteron
# Prolactine
# Steroïdprofiel
# Testosteron
# TSH 0
# AMH (Anti-Müllers Hormoon)
# Albumine
# Erytrocyten
# Neutrofielen granulocyten abs.
# Leukocyten
# Erytroblasten abs.
# Tot. Eiwit
# Trombocyten
# 1.25-di-OH Vitamine D
# Trial/Studie
# DNAProject
# Hematocriet
# Fosfaat
# 25-OH Vitamine D
# Krea. Se-GFR
# Magnesium
# ACTH
# DHEA-sulfaat
# Chromogr.A
# NSE
# 3-MT
# Metanefrine
# Normetanefrine
# SHBG
# CRP
# Glucose
# Act.bicarbonaat bloedgas
# Base excess bloedgas
# Geion. Calcium 7.4 bloedgas
# Chloride bloedgas
# COHB bloedgas
# O2-content bloedgas
# Glucose bloedgas
# Hemoglobine bloedgas
# Geion. Calcium bloedgas
# Kalium bloedgas
# Lactaat bloedgas
# MetHb
# Natrium bloedgas
# P50 bloedgas
# pCO2 bloedgas
# pH bloedgas
# pO2 bloedgas
# O2-saturatie bloedgas
# Std.bicarbonaat bloedgas
# Glucose/POCT
# Basofiele granulocyt DA
# Basofiele granulocyten abs DA
# Eosinfiele granulocyten abs DA
# Immature granulocyten abs DA
# Lymfocyten abs DA
# Monocyten abs DA
# Neutrofiele granulocyten abs DA
# Eosinofiele granulocyt DA
# Immature granulocyten DA
# Lymfocyten DA
# Monocyten DA
# Neutrofielen granulocyten DA
# Amylase
# Antistoffen tegen endomysium (IgA)
# HbA1c
# TSH screening
# Antistoffen tegen tTG (IgA)
# Calcium gecorrigeerd
# CKD-EPIeGFR (kreat)
# APTT
# INR
# PT
# Cholesterol
# Cholesterol-HDL Ratio
# HDL-Cholesterol
# IgA
# LDL-Cholesterol
# Triglyceride
# Antistoffen tegen schildklier (TPO)
# Antistoffen tegen gliadine (IgG)
# B-Cellen (Coly)
# T-Cellen (Coly)
# CD4+T-Cellen (Coly)
# CD8+T-Cellen (Coly)
# NK-Cellen (Coly)
# Chol/HDL
# Bezinking
# Leukocyten(DYLE)
# Trombocyten(DYTR)
# Hemoglobine (OV)
# Insuline
# Order
# Bloedgroep lang
# Kruisbloed
# Rhesus/K-typering
# Antistof screening
# Angiotensine converting enzyme
# NT-pro-BNP
# Soluble IL-2 Receptor
# Bloedgroep kort
# Urinezuur
# soluble IL-2R
# Vitamine B12
# Vitamine B1 volbloed
# Studie afname
# Dopamine
# Epinefrine
# Norepinefrine
# T3
# CYP1A2 genotypering
# CYP2C19 genotypering
# CYP2C9 genotypering
# CYP2D6 genotypering
# CYP3A4 genotypering
# DNA Isolatie nummer
# bloedafname(BAF1) - test bepaling tbv declaratie
# Non-HDL cholesterol
# Order(ORD1) - test bepaling tbv declaratie
# bloedafname polikliniek(BAF3) - test bep tbv decl
# ~ bloedafname(BAF4)
# IGF-BP3
# TSH (Vitros ECIQ)
# Beoordeling virologie
# CLIA anti HBc
# CLIA IgG HCV
# CLIA-K HBsAg
# actief B12
# Vitamine B6 volbloed
# Ferritine
# Homocysteine
# ACL IgG
# ACL IgM
# APTT-FSL Screen
# Beta2GPI IgG
# Beta2GPI IgM
# Conclusie
# dRVVT Screen
# hs-AMH (Anti-Müllers Hormoon)
# Gamma-fractie_C
# Mprot IgG-K1
# IgG
# IgM
# Mproteine  spectrum
# Nieuwe patient / follow up (MProt)
# Tryptase
# CLIA HIV combo
# CLIA HIV-p24
# CLIA Ig HIV
# Order(ORD6)
# PTH-intact
# Rhesus
# papier order(PRD6)
# CK
# CKMB massa
# hsTnT
# Antistoffen tegen TSH-receptor
# Antistoffen tegen schildklier (Tg)
# Botspecifieke Alkalische Fosfatase
#  b-CTx
# Foliumzuur
# P1NP
# Albumine-fractie_C
# Alpha1-fractie_C
# Alpha2-fractie_C
# Beta-fractie_C
# Inhibine B
# Macroprolactine
# Groeihormoon
# 11-Desoxycortisol
# Antistoffen tegen TSH-R
# FT4 screening
# Act.bicarbonaat
# Transfer.sat
# IJzer
# Transferrine
# Glucose/POCT(PPGL)
# ~ Base excess(PABE)
# ~ Act.bicarb.(PABI)
# ~ cCa++(7.4)(PCA7)
# ~ Chloride(PCL)
# ~ COHB(PCOH)
# ~ Glucose(PGL)
# ~ Hemoglobine(PHB)
# ~ Geion. Ca(PICA)
# ~ Kalium(PKA)
# ~ Lactaat(PLAC)
# ~ MetHb(PMEH)
# Natrium(PNA)
# ~ pO2(PO2P)
# ~ pCO2(PPCO)
# ~ pH(PPH)
# ~ O2-saturatie(PSAT)
# ~ Std.bicarb.(PSBI)
# Reticulocyten abs.
# Transferrine saturatie
# Chloride
# CLIA IgG HSV 1 en 2
# CLIA IgM VZV
# CLIA-K IgG VZV
# PCR HSV-1
# PCR HSV-2
# PCR VZV
# Digoxine
# Carbamazepin
# Medische Genetica (Genoomdiagnostiek) Utrecht
# VEGF Vasculair endotheliale groeifactor
# papier order(PRD4)
# Cystatine C
# Aldosteron
# Renine
# Aldosteron (LCMS)
# Calcitonine
# CEA
# Haptoglobine
# Weigeren nabep Chemie AKC
# Accepteren nabep Chemie AKC
# Folz. ery's
# Foliumzuur Hemolysaat
# Hematocriet(HT5)
# Apo-B
# anti-Tg
# Thyreoglobuline
# Progesteron
# Reverse-T3
# T4
# hs-Thyreoglob. antistoffen
# hs-Thyreoglobuline
# hs-Thyreoglobuline recovery
# Lipase
# Dir. Bilirubine
# C4
# Spijtserum (Endo)
# Antistoffen tegen gliadine (IgA)
# Erytropoëtine
# Directe Coombs
# Reti-index
# Rhesus
# RUNX1-RUNX1T1
# ASXL1 mutatie
# CBFB-MYH11 Taqman
# CEBPa mutatie
# Conclusie(CONM)
# EVI1 expressie
# FLT3-ITD
# FLT3-TKD
# Consult 0027 Moleculair
# KIT mutatie
# % CD14(LC14)
# % CD15(LC15)
# % CD19(LC19)
# Smk/L ratio(LKLR)
# Sequentie analyse
# NPM1 mutatie
# RUNX1 mutatie
# TP53 mutatie
# Vriesnummer Leukemie
# % afwijkende populatie
# % basofiele granulocyten
# CML buis
# CML-conclusie
# CML_DECL
# afwijkende populatie
# % neutrofiele granulocyten
# % myeloide voorlopercellen
# White Blood Cell Count
# FVIII-act
# PFA-Col/EPI
# vWF-act.
# vWF antigeen
# vWF collageenbinding
# HCG+beta HCG
# Gastrine
# Dummy(DUMW)
# Stolbuis 6ml zonder gel
# Serum aliquot 1x
# Serum aliquot 2x
# Serum aliquot 3x
# Serum aliquot 4x
# Serum aliquot 5x
# Eosinofielen granulocyten abs.
# Basofiele granulocyten DM
# Dummy(DFFW)
# Basofiele granulocyt abs DM
# Eosinofiele granulocyten abs DM
# Lymfocyten abs DM
# Monocyten abs DM
# Segmenten abs DM
# Eosinofiele granulocyten DM
# Fragmentocyten
# Hypogranulatie neutrofielen
# Hypersegmentatie
# Lymfocyten DM
# Monocyten DM
# Segmenten DM
# Afw. lymfocyten suspect reactief
# MethylMzuur
# Verzending naar overige instanties
# 21-Deoxycortisol
# Cortisol (lcms)
# Corticosteron
# Dihydrotestosteron
# CLIA IgG HTLV 1 of 2
# b2-Microglobuline
# Free Kappa
# Free Lambda
# Ratio FKappa/FLambda
# Ratio fk/fl
# Vrije lichte ketens
# HLA typering ABC
# PCR-K HBV cap-ctm
# Antitrombine
# Factor X
# Lichaampjes van Döhle
# Metamyelocyten abs DM
# Myelocyten abs DM
# Staafkernige granulocyten abs DM
# Metamyelocyten DM
# Myelocyten DM
# Staafkernige granulocyten DM
# Plasmacellen abs DM
# Plasmacellen DM
# Toxische korreling
# D-dimeren
# Mprot IgG-L1
# Antiplasmine
# Free Kappa optilite
# Free Lambda optilite
# Ratio fk/fl_opti
# Mprot IgG-L2
# Oligopatroon
# Opmerkingen bloed
# ACTH in serum (dummy)
# Vrij_Testosteron
# PSA
# PSA1
# Fibrinogeen Clauss
# ROTEM EXTEM
# ROTEM FIBTEM
# ROTEM INTEM
# ROTEM HEPTEM
# APTT ratio
# Trombintijden 10E
# Verzending naar UMCU
# Subklasse IgG1
# Subklasse IgG2
# Subklasse IgG3
# Subklasse IgG4
# Pro-insuline
# Nabepaling Endocrinologie
# Valproine
# ALAT (GPT)
# ASAT (GOT)
# Bloedafname
# ~ Krea. Se-GFR(GFR2)
# ~ Glucose(GLU1)
# ~ Hemoglobine
# Kalium(K1)
# Kreatinine(KRE1)
# ~ MCV
# Natrium(NA1)
# Order(ORD1)
# PNOP trial
# ~ RDW
# Venflon
# Beclomethason
# Dexamethason / Betamethason
# Exogeen Steroïd profiel
# Fludrocortison
# 6-alfa-methylprednisolon
# Prednison
# Prednisolon
# Levetiracetam
# Factor XI
# Factor XIII
# PFA-Col/ADP
# vWF-multimeren
# Weigeren nabep Hema AKC
# Accepteren nabep Hema AKC
# Agg. ADP
# Agg. Arachidonzuur
# Agg. Collageen
# Agg. Epinefrine
# Agg. Ristocetine H
# Agg. Ristocetine L
# Agg. TRAP
# Agg. U46619
# Myoglobine
# C3
# Complement CP
# Totaal IgE
# Antistoffen tegen pariëtale cellen
# Antistoffen tegen bijnierschors
# Antistoffen tegen gonadale steroïd-prod cellen
# Antistoffen tegen bijnierschors screening
# Antistoffen tegen H+K+ATPase (GPA)
# PLGF_AKC
# PreRisk Calculator
# SFLT_AKC
# sFlt-1/PlGF Ratio
# Galzuren in serum
# Hemoglobine/POCT
# GFR kinderen_elp
# C-peptide
# Status update tbv HiX
# AMC Klinische Genetica / DNA diagnostiek Amsterdam
# Leptine
# CLIA Ig HAV
# CLIA IgM CMV
# CLIA IgM HAV
# CLIA-K IgM EBV VCA
# EIA IgG HEV
# EIA IgM HEV
# PCR hepatitis E
# Toevoeger
# Nabepaling Hemostase
# SCC
# Lipoproteine A
# Antistoffen tegen mitochondriën screening
# Vrij T3
# APTT-FSL Ratio
# Proteïne C act.
# FV Leiden
# Protrombine-gen variant
# Proteïne S act.
# Spijtplasma
# Proteïne S totaal
# Proteïne S vrij
# Vriesnummer Stolling
# ANA
# ANA I-IF cytoplasmatisch patroon
# ANA I-IF kern patroon
# Cryoglobuline
# Koude Agglutininen
# Antistoffen tegen EJ mbv Myositis blot
# Antistoffen tegen Jo-1 mbv Myositis blot
# Antistoffen tegen Ku mbv Myositis blot
# Antistoffen tegen Mi-2alpha mbv Myositis blot
# Antistoffen tegen Mi-2beta mbv Myositis blot
# Antistoffen tegen MDA5 mbv Myositis blot
# Antistoffen tegen NXP2 mbv Myositis blot
# Antistoffen tegen OJ mbv Myositis blot
# Antistoffen tegen PL-12 mbv Myositis blot
# Antistoffen tegen PL-7 mbv Myositis blot
# Antistoffen tegen PM-Scl100 mbv Myositis blot
# Antistoffen tegen PM-Scl75 mbv Myositis blot
# Antistoffen tegen SAE1 mbv Myositis blot
# Antistoffen tegen SRP mbv Myositis blot
# Antistoffen tegen TIF-1gamma mbv Myositis blot
# Myositis antigenen
# IgD
# Antistoffen tegen intrinsic factor
# CD4CD8 ratio (Coly)
# Vitamine A bloed
# Vitamine E bloed
# CA 19.9
# Zink in volbloed
# Hematocriet(PHT)
# Opslag
# Free Kappa immage
# Free Lambda immage
# Mprot IgM-K
# Ratio fk/fL immage
# Oorspronkelijk Mproteine
# Oorspronkelijk type (MPROT)
# Dummy(DFFT)
# Macrotrombocyten
# MPV
# Bloedgroep lang Manuele Test
# Antistof screening Manuele Test
# Bloedgroep kort Manuele Test
# PSA10
# EIA Ig HDV
# FSI-CELH
# Kruisserum
# Ag-Fy(a)
# Ag-Fy(b)
# Ag-Jk(a)
# Ag-Jk(b)
# Ag-s
# Bldgrkaartje
# Tekst Bloedgroepkaartje
# Dummy(DFFR)
# Neutrofielen Manueel
# Kruisproef
# Sanquin A'dam
# Opmerkingsveld Elpado Bloed
# CA 125
# Rhesus/K-typering Manuele Test
# TSH10
# CA 15.3
# Spijtserum COVID19
# Lymfo absoluut tbv NLR
# Neutro/Lymfo ratio
# Procalcitonine
# Spijt EDTA plasma
# Spijt heparineplasma
# Spijt serum
# NGAL in bloed
# Everolimus (certican)
# Inhibine A
# Multiple congenitale afwijkingen
# Chromosoomonderzoek overig (HEP)
# Chromosoomonderzoek overig (EDTA)
# Antistoffen tegen IA-2
# Antistoffen tegen eilandjes van Langerhans
# Antistoffen tegen GAD
# ANCA I-IF Ethanol fixatie
# ANCA I-IF Formaline fixatie
# cANCA
# Antistoffen tegen CCP
# Reumafactoren
# pANCA
# Lactaat Cobas
# Lactaat/Pyruvaat ratio
# Pyruvaat Cobas
# Immuno_chem ALB in BL
# Immuno_chem IgG in BL
# Antistoffen tegen ENA EliA-Symphony
# Antistoffen tegen SS-A (52kD)
# Antistoffen tegen SS-B
# Vrije vetzuren
# Antistoffen tegen amfifysine
# Antistoffen tegen Caspr2
# Antistoffen tegen CV2 (CRMP5)
# Antistoffen tegen DPPX
# Anti-amfifysine mbv EuroImmun PNS blot
# Anti-CV2 mbv EuroImmun PNS blot
# Anti-Hu mbv EuroImmun PNS blot
# Anti-Ma2 mbv EuroImmun PNS blot
# Anti-Ri mbv EuroImmun PNS blot
# Anti-TR mbv EuroImmun PNS blot
# Anti-Yo mbv EuroImmun PNS blot
# Antistoffen tegen glycine-receptor
# Antistoffen tegen Hu
# Cerebellum Korrellaag
# Antistoffen tegen LGI1
# Antistoffen tegen Ma1
# Antistoffen tegen Ma2 (Ta)
# Cerebellum moleculaire laag
# Cerebellum overig
# Cerebellum Purkinje cellen
# Antistoffen tegen Ri
# Antistoffen tegen Tr
# Cerebellum Witte stof
# Antistoffen tegen Yo
# Klinische Genetica VU (DNA en Eiwitdiagnostiek) Am
# CLIA-K anti HBs
# PCR-K HCV cap-ctm
# SEQA HCV
# AFP
# Klinische Genetica LUMC (Genoomanalyse) Leiden
# Antistoffen tegen dsDNA
# Factor V
# Antistoffen tegen fosfolipase A2-receptor
# Plasminogeen
# CALR mutatie
# ct_Albumine
# DNA concentratie A
# DNA concentratie B
# JAK2 exon12 mutatie
# JAK2 V617F mutatie
# MPL mutatie
# klinische genetica DNA diagnostiek unit Maastricht
# Antistoffen tegen endomysium (IgG)
# Antistoffen tegen tTG (IgG)
# Genetica St. Radboud
# Overige bepalingen extern
# Antistoffen tegen gladde spier
# Antistoffen tegen lever-nier microsomen
# Antistoffen tegen mitochondriën
# Antistoffen tegen F-actine
# Antistoffen tegen gladde spier screening
# Antistoffen tegen mitochondriaal M2
# Antistoffen tegen LKM-1
# Antistoffen tegen SLA
# Antistoffen tegen gladde spier titer
# PCR-K CMV IU/ml
# PCR-K EBV IU/ml
# PCR-K HEV
# Latex
# Inhalatiemix
# ANA titer
# C1 esteraseremmer activiteit
# C1Q complement
# Antistoffen tegen CenpB
# IgE antistofprofiel tegen allergeen componenten
# Antistoffen tegen Jo-1
# Antistoffen tegen RNP
# Antistoffen tegen SS-A (60kD)
# Antistoffen tegen Sm
# Antistoffen tegen Scl70
# Tomaat
# POCT INR
# POCT PT
# Amiodaron
# Desethylamiodaron
# PT INR
# Osmolaliteit(OSM)
# Overige bepaling Oncolab
# GENO studiebuis 1
# Multomab
# Ag-K
# Trombinetijd 5E
# Colloid osm.druk
# AMC Genoomanalyse (Neurogenetica) Amsterdam
# Lithium
# papier order(PRD1) - test bepaling tbv declaratie
# Apo-A1
# Antistoffen tegen Cenp-A mbv SSc blot
# Antistoffen tegen Cenp-B mbv SSc blot
# Antistoffen tegen fibrillarine mbv SSc blot
# Antistoffen tegen NOR90 mbv SSc blot
# Antistoffen tegen RNA Pol III 11kD mbv SSc blot
# Antistoffen tegen RNA Pol III 155kD mbv SSc blot
# Antistoffen tegen Scl70 mbv SSc blot
# Antistoffen tegen PM-Scl75 mbv SSc blot
# Systemic Sclerosis antigenen
# Antistoffen tegen Ku mbv SSc blot
# Antistoffen tegen PM-Scl100 mbv SSc blot
# Antistoffen tegen Th/To mbv SSc blot
# Decl_Medische Immunologie - test bepaling tbv decl
# Ag-A1
# Ag-P1
# PANEL informatie
# Anti-P1
# Identificatiepanel
# Antistof screening buisjes
# PNOP
# Pipamperon
# Aspergillus fumigatus (IgG)
# Antistoffen tegen AMPA-receptor
# Antistoffen tegen GABAb-receptor
# Antistoffen tegen NMDA-receptor
# Antistoffen tegen VGKC-complex
# TPMT genotypering
# Kobalt
# Ammoniak
# Verzending naar RadboudUMC
# Copeptine
# ~ Eo's(CEO4)
# Tacrolimus (FK506)
# Mycophenolat
# CLIA IgG CMV
# CLIA-K IgG EBV VCA
# CONS-DBC-P
# PCR-K BKV
# CLIA-K IgG EBV EA
# CLIA-K IgG EBV NA
# Basofiele granulocyten abs
# Eosinfiele granulocyten abs
# Immature granulocyten abs
# Lymfocyten abs
# Monocyten abs
# Neutrofiele granulocyten abs
# Leuko differentiatie
# 6-Methyl  mercaptopurine
# 6-MMP/6-TGN
# 6-Thioguanine nucleotiden
# LUMC Donor specifieke antistoffen
# LUMC Screening HLA antistoffen
# Ontvanger Bloedgroep
# Ontvanger Dialysecentrum
# Ontvanger Gewicht
# Ontvanger Lengte
# A-locus (LMX)
# B-locus (LMX)
# C-locus (LMX)
# DNA HLA-typering
# DQB1-locus (RLB)
# DRB1-locus (RLB)
# DRB345-locus (RLB)
# LUMC ET nummer
# Luminex screening klasse 1
# Luminex screening klasse 2
# Luminex Single Antigen klasse 1
# Luminex Single Antigen klasse 2
# Serologisch equivalent
# Titer Anti-B (IgG)
# Titer Anti-B (IgM)
# Vancomycine
# ~ Albumine
# Calcium(CA1)
# CRP(CRP2)
# LD
# Magnesium(MG1)
# Fosfaat(P1)
# Tot. bilirub
# Tot. eiwit(TE1)
# Baso's(ZBA)
# Eo's(ZEO)
# Dummy(ZFFW)
# Lymfocyten(ZLY)
# zMyelocyten
# Metamyelo's
# Monocyten(ZMO)
# Promyelo's
# ~ Segmenten
# Staven
# tox.korrel.
# Methotrexaat
# ~ Reti-index(DARI)
# Retic. abs.(RET2)
# HLA typering DRB1, DQB1, DPB1
# HIT
# Atypische lymfocyten
# Blasten DM
# Kernklievingen
# Fibrinogeen
# Vacuolisatie van de Lymfocyten
# Donor naam
# Donor patientnummer
# Informatieve loci
# Cyclosporine
# Large Granular Lymphocytes
# Promyelocyten DM
# Kruisproef Manuele Test
# Absoluut CD19 + B-cellen
# Absoluut CD3 + 4 + T-cellen
# Absoluut CD3 + 8 + T-cellen
# Absoluut CD3¯ CD16/56+
# Absoluut CD3 + T-cellen
# %  Donor bloed
# %  Donor T-cellen
# FU/post transplantatie bloed
# FU/post transplantatie T-cellen
# % zuiverheid T-cellen
# Difterie
# Conclusie antistoffen Haemophilus Influenzae
# HIB antistoffen
# Meningokokken type C
# Streptococcus pneumoniae serotype 1
# Streptococcus pneumoniae serotype 3
# Streptococcus pneumoniae serotype 4
# Streptococcus pneumoniae serotype 5
# Streptococcus pneumoniae serotype 8
# Streptococcus pneumoniae serotype 14
# Streptococcus pneumoniae serotype 20
# Streptococcus pneumoniae serotype 6B
# Streptococcus pneumoniae serotype 7F
# Streptococcus pneumoniae serotype 9V
# Streptococcus pneumoniae serotype 15B
# Streptococcus pneumoniae serotype 18C
# Streptococcus pneumoniae serotype 19A
# Streptococcus pneumoniae serotype 19F
# Streptococcus pneumoniae serotype 23F
# Streptococcus pneumoniae serotype 33F
# Conclusie antistoffen Streptococcus pneumoniae
# Polio type 1 titer
# Polio type 3 titer
# Tetanus
# RhD / Rhc immunisatie
# Anti-D profylaxe
# Promyelocyten abs DM
# Huisstofmijt D1
# Katte-roos
# Honde-roos
# Graspollen (kropaar)
# Berk
# Bijvoet
# Antistoffen tegen aquaporine-4
# Antistoffen tegen MOG
# PTH - Turbo
# Azoöspermie/oligospermieAZFA/b/c regio's (y-deleti
# Afwijkende geslachtelijke ontw. en/of functie
# HB27 buis 1
# HB27 buis 2
# HB27 buis 3
# HLA-B27 Conclusie
# HLA-B27_DECL
# HB27-PCR
# Conclusie Pseudotrombopenie
# Trombo_citraat
# Imm Platelet fraction
# dRVVT Confirm
# dRVVT Mix
# dRVVT Ratio
# Trombocyten morfologie
# CLIA-K HBeAg
# T-Cellen (THIV)
# CD4+T-Cellen (THIV)
# CD4CD8 ratio (THIV)
# CD8+T-Cellen (THIV)
# PCR B19 virus
# G-6-PD
# % PI-deficiente erytrocyten
# PK
# % PI-deficiente monocyten
# % PI-deficiente neutrofiele granulocyten
# PNH buis 1
# PNH buis 2
# PNH-conclusie
# PNH_DECL
# Sferocyten
# Stomatocyten
# ADAMTS13
# ADAMTS13 inhibitor
# Nabepaling Immunologie
# Antistoffen tegen GFAP
# Absoluut aantal afwijkende cellen
# Absoluut aantal afwijkende cellen
# % afwijkende populatie
# AML buis 1
# CBL mutatie
# Koper in bloed
# % eosinofiele granulocyten
# % (pro)erytroblasten
# EZH2 mutatie
# GATA2 mutatie
# Karyotypering
# Tumorcytogenetica tekst 1
# Lood in bloed
# MDS-conclusie
# MDS_DUM
# % monocyten
# PDP_DUM
# % promyelocyten
# SF3B1 mutatie
# U2AF1  mutatie
# DAT C3c
# DAT C3d
# DAT IgA
# DAT IgG
# DAT IgM
# DAT typering
# Verzending naar Sanquin
# 200 Mentale retardatie
# FMR1
# Verstandelijke beperking
# Overig
# CD4/CD8 ratio
# % CD4+ T-cellen
# % CD8+ T-cellen
# LST buis
# % NK-cellen
# % voorloper-B-cellen
# % plasmacellen
# % B-cellen
# % T-cellen
# Screening Hemato. Malign. Conclusie
# Screening hematologische maligniteit_DECL
# SmIgK/SmIgL ratio
# Anti-E
# Uitsluitpanel
# 106 Marfanoide kenmerken
# 223 Psychose
# Dragerschap array afw. in de familie
# Verzending naar AMC
# Antistoffen tegen rRNP mbv Phadia 250
# Antistoffen tegen rRNP
# isoAF lever
# isoAF gal
# isoAF bot
# isoAF darm
# isoAF placen
# Alfa1-antitrypsine
# Ceruloplasmine
# TBG
# LUMC 1e typering donor
# LUMC 2e typering van donor
# LUMC Familiekruisproef donor
# LUMC Cross-over kruisproef donor
# LST-conclusie
# LST_DECL
# Rijp T buis
# VAF_ASXL1 mutatie
# SANQ Next-Generation Sequencing
# SANQ HLA klasse I antistofspecificatie mbv luminex
# Fase Test
# Beoordeling HMD
# VAF JAK2 V617F mutatie
# Aldosteron / Renine ratio
# Dummy pico-AMH
# EDTA plasma aliquot 1x
# EIA IgM SARS CoV-2
# EIA Ig SARS CoV-2
# CKD-EPIeGFRcysC
# Testosteron Cito
# CLIA IgG CMV Avid.
# 3OH-Boterzr
# ~ Neutrofielen(GRA1)
# LGL(ZLGL)
# atyp.lymfo's
# hypersegm.
# PCR ADV
# Niet intacte cellen
# Afw. lymfocyten suspect maligne
# CLIA IgG mazelen
# LIA HCV C1
# LIA HCV C2
# LIA HCV conf
# LIA HCV E2
# LIA HCV NS3
# LIA HCV NS4
# LIA HCV NS5
# LIA strept. HCV
# TMA-K HBV
# TMA-K HCV
# FVIII-act chromogeentest
# Ontvanger ET nummer
# Order_HLA-typering leverpatient
# FLCN
# CYLD
# Anti-Xa spiegel
# bloedafname(BAFE)
# Order(ORDE)
# Prader-Willi syndroom (methylering)
# HLA-DQ22
# HLA-DQ25
# HLA-DQ2 HLA-DQ8 Conclusie
# HLA-DQ8
# Pre-albumine
# Lamotrigine
# Glucagon
# Pancreas Polypeptide
# Alpha-subunits
# Beta-trace proteine
# BCEL-SS_DECL
# % CD21-CD38- B
# cm CD4
# cm CD8
# em CD4
# em CD8
# Howell-Jolly
# % IgA+ memory B
# % IgE+ memory B
# % IgG+ memory B
# % IgM+ memory B
# memory B
# naief CD4
# naief CD8
# naief matuur B
# natural effector B
# PID POSTGC buis 1
# PID PREGC buis 1
# PID SCID buis 1
# PID SCIDEX buis 1
# PID SCR buis 1
# PID TCEL buis 1
# PID TRU buis 1
# % plasmablasten
# TCEL-SS_DECL
# Transitioneel B
# Complement AP
# Complement MBL
# COLA
# BCR-ABL genfusie multiplex
# Infliximab
# anti-stoffen tegen Infliximab
# CLIA-K IgG SARS-CoV-2
# PT INR(ASIR)
# APTT(ASN)
# APTT ratio(ASNR)
# PT(ASTP)
# Antistoffen tegen acetylcholine-receptor
# VGCC CPM NSB
# VGCC CPM Totaal
# Bepaling diversen extern
# Antistoffen tegen IgLON5
# Antistoffen tegen MuSK
# Antistoffen tegen VGCC
# CD19 memory
# CD19 naief
# CD4 memory
# CD4 naief
# CD4 totaal
# CD8 memory
# CD8 naief
# CD8 totaal
# Dendritische cellen
# monocyten
# B cellen
# T cellen
# NK cellen
# Mycophenolat PL
# Tacrolimus
# Trombocyten aantal
# CLIA anti HBe
# Antistoffen tegen SS-A 52kD mbv ANA blot
# Antistoffen tegen SS-A 60kD mbv ANA blot
# Antistoffen tegen CenpB mbv ANA blot
# Antistoffen tegen dsDNA  mbv ANA blot
# Antistoffen tegen histonen mbv ANA blot
# Antistoffen tegen Jo-1 mbv ANA blot
# Antistoffen tegen SS-B mbv ANA blot
# Antistoffen tegen AMA-M2 mbv ANA blot
# Antistoffen tegen nucleosomen mbv ANA blot
# Antistoffen tegen PCNA mbv ANA blot
# Antistoffen tegen PM-Scl100 mbv ANA blot
# Antistoffen tegen rib-P-prot mbv ANA blot
# Antistoffen tegen RNP/Sm mbv ANA blot
# Antistoffen tegen Scl70 mbv ANA blot
# Antistoffen tegen Sm mbv ANA blot
# Antistoffen tegen SS-A (52 en 60kD) mbv Phadia 250
# % CD4+ cellen
# % CD8+ cellen
# % cm CD4
# % cm CD8
# % em CD4
# % em CD8
# % naief CD4
# % naief CD8
# Nabepaling Allergologie
# Aniso Trombo
# Baso's
# Eo's
# Hypochroom
# Lymfocyt
# Microcyten
# Monocyt
# Overige opm.
# Segment
# Hemoglobine (HOLS)
# Hematocriet (HOLS)
# Leukocyten (HOLS)
# Neutrofielen (HOLS)
# Trombocyten (HOLS)
# SCRAL buis 1
# SCRAL buis 2
# SCRAL buis 3
# SCRAL-conclusie
# SCRAL_DECL
# Adrenaline
# Noradrenaline
# 3-MT urine
# Trombocyten manueel
# Micro Bezinking
# Accepteren nabep Farma AKC
# ~ bloedafname(BAF6)
# Toevoeger(TOES)
# Voriconazol
# AMH_AKC
# Oxaalzuur
# anti-stoffen tegen Adalumimab
# Adalimumab
# Transferrine saturatie_
# PT INR(TSIR)
# ~ PT(TSPT)
# Everolimus (trail)
# CLIA-K IgG rubella
# Opslag S nummer
# CLIA IgG B19 virus
# CLIA IgM B19 virus
# CLIA IgM HSV
# CLIA IgM rubella
# ~ Hematocriet
# Urinezuur(URZ1)
# IG(imm.gran)(ZIGP)
# Neutrofielen(ZNEU)
# EDTA-buis 6ml
# TSC2
# Broer/Zus 1
# Broer/Zus 2
# Vader
# Moeder
# Rh-fenotype
# Blasten abs DM
# Vitamine K
# Factor VII
# ~ Erytrocyten
# Hemolyse
# GASCODE
# DPYD genotypering
# CKD-EPIeGFR
# Asp.fum.IgE
# Krab
# Garnaal
# Mossel
# Inktvis (Pacific inktvis)
# Kreeft
# Erytrocyten morfologie
# HLA antistoffen screening
# PCR HHV-6
# Vrije tekst1 bloed
# Macropolycyten
# Rijpingsdissociatie
# IL6_AKC
# Vitamine A bloed
# Hb-electroforese
# Hb-pathie conclusie
# HPLC HbA0
# HPLC HbA2
# HPLC HbF
# LMNA
# LUMC 1e typering van ontvanger (nier)
# Donor ET nummer
# Donor geboorte datum
# Donor Geslacht
# Relatie Donor Ontvanger
# Conclusie kruisproef
# FACS kruisproef
# Order_Kruisproef met levende donor HEP
# Order_Kruisproef met levende donor SERUM
# Lymfocytenkruisproef
# PRA Spoed (klasse I) met DTT
# PRA Spoedscreening (klasse I)
# Specificiteiten (cumulatief)
# Spoedscreening (klasse I)
# Spoedscreening (klasse I) met DTT
# Virtuele PRA
# Datum Bloedtransfusie
# Order_Screening nierpatient na bloedtransfusie
# Leuko morfol(ZLMO)
# Paardenroos
# Cavia epit
# Vitamine B3 / Nicotinezuur
# HBF buis 1
# HBF buis 2
# HBF buis 3
# HBF Conclusie
# HBF_DECL
# %HBF
# PCR-K HIV 1
# TMA-K HIV-1
# DNA GLIO
# Vrij PSA
# PSA Ratio
# Trf reactie melding (formulier)
# Factor II
# Factor IX
# Ratio fK/fL(CRKL)
# Trombocytenaggregaten
# Covid 19 EDTA plasma
# Covid 19 serum
# COVID citraatplasma spijt
# Membraanpakket
# Eluaat zuur
# 950 Controle therapie Acylcarnitines
# Genetica UMCG Groningen
# Desmethylclozapine
# Clozapine
# Duivenmix (IgG)
# Papegaaimix (IgG)
# Alternaria alt. (IgG)
# Parkietenmix (IgG)
# Thermoactinomyces vulgaris IgG
# Macrocytose
# Microcytose
# Hemoglobinopathieën
# Lactaat
# Anti-M
# OAg-M
# Renine serum (dummy)
# CYP2B6 genotypering
# Eiwit (kippenei)
# Melk (koe)
# Vis (kabeljauw)
# Tarwe
# Pinda
# Soja
# Voedselmix
# Doornappelcellen
# HLA laboratorium Leiden
# BLGR donor NTX
# Donormateriaal
# Aspec.react.
# PTH-rP
# V.I.P. Vasoactief intestinaal peptide
# Paracetamol
# HLA-B*5701 genotypering
# LIA anti HIV1 GP120
# LIA anti HIV1 GP41
# LIA anti HIV1 p17
# LIA anti HIV1 p24
# LIA anti HIV1 p31
# LIA anti HIV2 GP105
# LIA anti HIV2 GP36
# LIA HIV conf
# LIA strept. HIV
# d-Aminolevulinincacid (d-ALA) in plasma
# d-Aminolevulinincacid (d-ALA)
# Coproporfyrine in plasma
# Porfobilinogeen (PBG) in plasma
# Protoporfyrine in plasma
# Uroporfyrine in plasma
# Antistoffen tegen MPO
# Antistoffen tegen PR3
# Opmerkingen
# BNP1
# Mprot IgA-L
# IgD optilite
# papier order
# Anti-K
# TBG electroforese
# Erytrocyten (HOLS)
# MCHC (HOLS)
# MCH (HOLS)
# MCV (HOLS)
# Reticulocyt (HOLS)
# Variatie Lymfo's
# BCLPD buis 1
# BCLPD buis 2
# BCLPD buis 3
# BCLPD buis 4
# Rijpe B-celmaligniteit-conclusie
# Rijpe B-celmaligniteit_DECL
# Gencontrole onverdund
# Gencontrole 1:10 verdund
# IGHV Tube A
# IGHV Tube B
# IGHV Tube C
# IGK Tube A
# IGK Tube B
# IG-KLON conclusie
# K/L los buis
# KL nummer
# TRB Tube A
# TRB Tube B
# TRB Tube C
# TRG Tube A
# TR-KLON conclusie
# Tot. Bilirubine bloedgas
# Vacuolen (neutro)
# Tobramycine
# Colistine
# Colistine vrije fractie
# Colistine vrij %
# Reusvormige granulocyten
# Amikacine
# Aciclovir
# PCR HAV
# MPV (HOLS)
# Lipoproteïne profiel (chol)
# Lipoproteïne profiel (trigl)
# Tot. eiwit(HTE4)
# Toevoeger(TOED)
# Verzending naar UMCG
# Serum Amyloid A
# EIA IgG HHV6
# IF IgM HHV6
# LUMC 3maandelijkse screening
# Antistoffen tegen TSH-R (TSI)
# Els (grauwe)
# Streptococcus pneumoniae serotype 6A
# ~ Base excess(BE1)
# ~ pH(BGP1)
# ~ Act.bicarb.
# ~ pCO2(PCO1)
# ~ pO2(PO1)
# ~ O2-saturatie(SA1)
# BCEL-SS-conclusie
# CD16.56+ abs
# CD19+ abs
# CD3+ abs
# naief B
# TCEL-SS-conclusie
# vWF Normandy
# Gentamycine
# ROTEM APTEM
# Nabepaling Apotheek
# MNC Isolatie
# Colistine A
# Colistine B
# VEGF-D Vasculair endothelial growth factor D
# ENDO_dummy
# Staaf
# NF1
# EIA-K IgA Adeno
# EIA-K IgA entero
# EIA-K IgG adeno
# EIA-K IgG entero
# EIA-K IgG M.pneu
# EIA-K IgM entero
# EIA-K IgM M. pneu
# PCR enterovirus
# PCR parecho
# Kruisproef Buistechniek
# Sanquin ZW
# Ag-Wr(a)
# Anti-Wr(a)
# Desclomiprame
# Clomipramine
# Antistoffen tegen skeletspier
# CYP3A5 genotypering
# IGene
# SLCO1B1 genotypering
# VKORC1 genotypering
# Boompollenmengsel 9
# Pecannoot
# papier order urine(PRD6)
# Alpha1 antitrypsine (Cobas)
# Covid 19 Heparine plasma
# KL-6
# suPAR
# Antistoffen tegen ovariumweefsel
# Antistoffen tegen testisweefsel
# Order(ORDH)
# pANCA titer
# Vrij T3 (dialyse methode)
# LIA HIV rapport
# AuAs-aspWarm
# Auto anti-C
# Auto anti-D
# Auto anti-e
# Beta-fractie_HiX
# B12_AKC
# 6TGN (aza)
# 6MMP (aza)
# Ratio 6MMP/6TGN (aza)
# SEQA HBV RT gen
# ~ O2-content(PCTO)
# ~ P50(PP50)
# Clobazam
# Everolimus
# CLIA IgG bof
# IF IgM bofvirus
# Zuurstofflow
# ps.Pelger Huet
# Antistoffen tegen MAG
# Mprot IgM-L
# verzending naar LUMC
# Monohydroxy carbazepine
# Antistoffen tegen elastase
# Conclusie(CONW)
# TRG Tube B
# % CD3
# CD4/8 ratio
# Auto anti-I
# CONS-DBC-Z1
# Rapamycine (Sirolimus)
# Subklasse IgG3
# Anti-Reco mbv EuroImmun PNS blot
# Antistoffen tegen recoverine
# Antistoffen Adalimumab
# ct_PBGD BCR-ABL multiplex
# RNA concentratie A
# RNA concentratie B
# BCR-ABL P210 Cepheid
# BCR-ABL_CEPHEID_niveau
# Conclusie HMD
# ct_ABL
# ct_BCR-ABL
# Detectielimiet_BCR-ABL
# IF144
# IF144L
# IFIT1
# IFIT3
# IFNABL
# Interferon type 1 signature
# MXA
#  Cyclospor.A(CYCB)
# Anti-GAD65 mbv EuroImmun PNS blot
# Anti-SOX1 mbv EuroImmun PNS blot
# Anti-Titin mbv EuroImmun PNS blot
# Anti-Zic4 mbv EuroImmun PNS blot
# LUMC 1e typering ontvanger
# LUMC Screening HLA 2 weken na transf
# CLIA HBsAg conf
# Antistoffen tegen dsDNA (CLIFT)
# Order_Screening Hartpatient
# E940 RhD neg. zwangeren 27e week onderzoek
# Hypochromasie
# Schietschijfcellen
# Rast.div.1
# Levertransplantatie
# Urinezuur op ijs
# tox.korrel

# %%
# Test data splitten uit totale dataset
# train_data2, test_data2 = train_test_split(df_comb, test_size=0.1, random_state=25)
# train_data = train_data2.drop(['Pt_no', 'Label'], axis=1)
# test_data = test_data2.drop(['Pt_no', 'Label'], axis=1)
# train_label = train_data2['Label']
# test_label = test_data2['Label']

# Waarom doen we de preprocessing ook niet gewoon hier

# %%
# # Define 10-fold stratified cross-validation
# cv_10fold = model_selection.StratifiedKFold(n_splits=10)

# for i, (train_index, val_index) in enumerate(cv_10fold.split(train_data, train_label)):    # Split the data in a train and validation set in a 10-fold cross-validation
#     data_train = train_data.iloc[train_index]
#     label_train = train_label.iloc[train_index]
#     data_val = train_data.iloc[val_index]
#     label_val = train_label.iloc[val_index]
 
#     # Pre-processing steps
#     # Impute data, but exclude the BMI in this. Add BMI again after imputation.
#     impute_train, impute_val = impute_data(data_train, data_val, df_decimal) #imputes data for all columns except BMI
#     impute_train['BMI'] = np.round(impute_train['Weight']/((impute_train['Length']/100)**2), decimals=2)
#     impute_val['BMI'] = np.round(impute_val['Weight']/((impute_val['Length']/100)**2), decimals=2)
#     impute_train = impute_train.loc[:,impute_train.columns!='Weight']
#     impute_val = impute_val.loc[:,impute_val.columns!='Weight']

# %%
# Define 10-fold stratified cross-validation
cv_10fold = model_selection.StratifiedKFold(n_splits=10)

for i, (train_index, val_index) in enumerate(cv_10fold.split(train_data, train_label)):    # Split the data in a train and validation set in a 10-fold cross-validation
    data_train = train_data.iloc[train_index]
    label_train = train_label.iloc[train_index]
    data_val = train_data.iloc[val_index]
    label_val = train_label.iloc[val_index]
 
    # Pre-processing steps
    # Impute data, but exclude the BMI in this. Add BMI again after imputation.
    impute_train, impute_val = impute_data(data_train, data_val, df_decimal) #imputes data for all columns 
    # Imputed lenght and weight, now calculate BMI from that and delete weight again
    impute_train['BMI'] = np.round(impute_train['Weight']/((impute_train['Length']/100)**2), decimals=2)
    impute_val['BMI'] = np.round(impute_val['Weight']/((impute_val['Length']/100)**2), decimals=2)
    impute_train = impute_train.loc[:,impute_train.columns!='Weight']
    impute_val = impute_val.loc[:,impute_val.columns!='Weight']
    
    # Find significant features per fold
    #sign, sign_features_dfs = find_sign_features(impute_train, label_train, train_index, ordinal_keys, binary_keys, continuous_keys, sign_features_dfs)
    sign, sign_features_dfs = find_sign_features(impute_train, label_train, train_index, ordinal_keys, binary_keys, continuous_keys, sign_features_dfs)

    # Make new dataframes with the significant features
    # train_sign=impute_train[sign]
    # val_sign=impute_val[sign]

    # Scale the data
    # scale_train, scale_val = scale_data(impute_train, impute_val, continuous_keys, ordinal_keys)

    # Define classifiers
    clf_RF_all = RandomForestClassifier()

    # Implement wrapper feature selection
    # sfs1 = sfs(clf_RF_all, k_features=5, forward= False, verbose = 1, scoring = 'neg_mean_squared_error')
    # sfs2 = sfs1.fit(impute_train, label_train) # executing feature selection
    # feat_names = list(sfs2.k_feature_names_)
    # print(f'These are the chosen features for this fold: {feat_names}')
    # Create and test three different models: random forest with all features, random forest with significant features only and support vector machine with only significant features
    # Random forest with all features: create model
    #tprs_RF_all, aucs_RF_all, auc_RF_all, spec_RF_all, sens_RF_all, accuracy_RF_all, gini_RF_all = pipeline_model(impute_train, label_train, impute_val, label_val, clf_RF_all, tprs_RF_all, aucs_RF_all, spec_RF_all, sens_RF_all, accuracy_RF_all, axis_RF_all)
    tprs_RF_all, aucs_RF_all, auc_RF_all, spec_RF_all, sens_RF_all, accuracy_RF_all, gini_RF_all = pipeline_model(impute_train, label_train, impute_val, label_val, clf_RF_all, tprs_RF_all, aucs_RF_all, spec_RF_all, sens_RF_all, accuracy_RF_all, axis_RF_all)

    # Random forest with significant features only: create model
    #tprs_RF_all, aucs_RF_all, auc_RF_all, spec_RF_all, sens_RF_all, accuracy_RF_all, gini_RF_all = pipeline_model(impute_train[sign], label_train, impute_val[sign], label_val, clf_RF_all, tprs_RF_all, aucs_RF_all, spec_RF_all, sens_RF_all, accuracy_RF_all, axis_RF_all) # met alleen maar significante features (lagere scores)
    # Random forest with all features: Calculate permutation feature importance
    #result = permutation_importance(clf_RF_all, impute_val[sign], label_val, n_repeats=10, random_state=42, n_jobs=2) # met alleen maar significante features (lagere scores)
    result = permutation_importance(clf_RF_all, impute_val, label_val, n_repeats=10, random_state=42, n_jobs=2) 
    # Create dataframe to store the results
    #df_feature_importance = pd.DataFrame({'Feature': (list(impute_train[sign].columns)), 'Feature importance mean': result.importances_mean, 'Feature importance std': result.importances_std})
    df_feature_importance = pd.DataFrame({'Feature': (list(impute_train.columns)), 'Feature importance mean': result.importances_mean, 'Feature importance std': result.importances_std}) # met alleen maar significante features (lagere scores)

    # Sort dataframe with the most important features first. Keep only the 5 most important features with .head()
    df_feature_importance_sorted = df_feature_importance.sort_values(by=['Feature importance mean'], ascending=False).head()
    # Append dataframe to list per fold. The list consists of i dataframes for the number of folds, showing the best 5 features per fold. This dataframe can be used for visualization.
    perm_importances_dfs.append(df_feature_importance_sorted)

    print(f'This is fold {i}')
# Out:
# This is fold 0
# This is fold 1
# This is fold 2
# This is fold 3
# This is fold 4
# This is fold 5
# This is fold 6
# This is fold 7
# This is fold 8
# This is fold 9

# %%
# Now, create a dataframe with all duplicate features removed
rel_features_df = pd.DataFrame()
for fold in perm_importances_dfs:
    rel_features_df = pd.concat([rel_features_df, fold])
rel_features_df = rel_features_df.drop_duplicates(subset=['Feature'])
# Make a list of the relevant features
rel_features = rel_features_df['Feature'].tolist()
print(f'These are the relevant features {rel_features}')
# Next, create new dataframes of the training and test data with only these relevant features and preprocess the data)
# Pre-processing steps
# Impute data
impute_train_rel, impute_test_rel = impute_data(train_data, test_data, df_decimal)
# Imputed length and weight, now calculate BMI from that and delete weight again
impute_train_rel['BMI'] = np.round(impute_train_rel['Weight']/((impute_train_rel['Length']/100)**2), decimals=2)
impute_test_rel['BMI'] = np.round(impute_test_rel['Weight']/((impute_test_rel['Length']/100)**2), decimals=2)
impute_train_rel = impute_train_rel.loc[:,impute_train_rel.columns!='Weight']
impute_test_rel = impute_test_rel.loc[:,impute_test_rel.columns!='Weight']
# Select only the relevant features
impute_train_fin = impute_train_rel[rel_features]
impute_test_fin = impute_test_rel[rel_features]

# Scale the data
scale_train_rel, scale_test_rel = scale_data(impute_train_rel, impute_test_rel, continuous_keys, ordinal_keys)
# Again, only select the relevant features
scale_train_fin = scale_train_rel[rel_features]
scale_test_fin = scale_test_rel[rel_features]

# Train a SVM and RF classifier using all the training data and validate on the remaining 10% of unseen data
# Define classifiers
clf_RF_fin = RandomForestClassifier()
clf_SVM_fin = SVC()

# Random forest with significant features only: create model
tprs_RF_fin, aucs_RF_fin, auc_RF_fin, spec_RF_fin, sens_RF_fin, accuracy_RF_fin, gini_RF_fin = pipeline_model(impute_train_fin, train_label, impute_test_fin, test_label, clf_RF_fin, tprs_RF_fin, aucs_RF_fin, spec_RF_fin, sens_RF_fin, accuracy_RF_fin, axis_RF_fin)

# Support vector machine with significant features only: create model with scaled data
tprs_SVM_fin, aucs_SVM_fin, auc_SVM_fin, spec_SVM_fin, sens_SVM_fin, accuracy_SVM_fin, gini_SVM_fin = pipeline_model(scale_train_fin, train_label, scale_test_fin, test_label, clf_SVM_fin, tprs_SVM_fin, aucs_SVM_fin, spec_SVM_fin, sens_SVM_fin, accuracy_SVM_fin, axis_SVM_fin)

# Combine true positive rates, areas under curve and axes for plotting mean ROC curves
# Out:
# These are the relevant features ['Length', 'CKD-EPI eGFR', 'KCH', 'END', 'Calcium', 'Alk.Fosf.', 'Brief_INT', 'Opnames_spec', 'Gamma-GT', 'Kalium', 'KIN', 'Kreatinine', 'GYN', 'Brief_GYN', 'Hemoglobine', 'ASAT', 'Glucose/PL', 'MCV', 'Natrium', 'Icterische index', 'Specialisms_hospitalization', 'RDW', 'Beeldvormende_verr', 'Neoplasms', 'LDH', 'Mental disorders', 'BMI', 'RRsyst', 'Radiologic_investigations', 'HR']

# %%
plt.show()

# Create a dictionary of the scores for the two models. Create dataframe for visualisation.
dict_scores = {'Model 1: Random Forest':[f'{np.round(accuracy_RF_fin, decimals = 2)}',
                                        f'{np.round(sens_RF_fin, decimals=2)}',
                                        f'{np.round(spec_RF_fin, decimals=2)}',
                                        f'{np.round(aucs_RF_fin,decimals=2)}',
                                        f'{np.round(gini_RF_fin,decimals=2)}'],
            'Model 2: Support Vector Machine':[f'{np.round(accuracy_SVM_fin,decimals=2)}',
                                        f'{np.round(sens_SVM_fin,decimals=2)}',
                                        f'{np.round(spec_SVM_fin,decimals=2)}',
                                        f'{np.round(aucs_SVM_fin,decimals=2)}',
                                        f'{np.round(gini_SVM_fin,decimals=2)}']}

df_scores = pd.DataFrame.from_dict(dict_scores, orient='index', columns=['Accuracy', 'Sensitivity', 'Specificity', 'Area under ROC-curve','Gini index'])

print(df_scores)
# Out:
#                                 Accuracy Sensitivity Specificity  \
# Model 1: Random Forest            [0.78]      [0.81]      [0.77]
# Model 2: Support Vector Machine   [0.78]      [0.76]       [0.8]
#
#                                 Area under ROC-curve Gini index
# Model 1: Random Forest                        [0.88]       0.76
# Model 2: Support Vector Machine               [0.89]       0.79
